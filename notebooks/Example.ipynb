# %%
from thorshammer.mjolnir import Mjolnir
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from thorshammer.mjolnir import Mjolnir
#
# ModuleNotFoundError: No module named 'thorshammer'
